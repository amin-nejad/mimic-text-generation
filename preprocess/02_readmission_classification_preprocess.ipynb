# %%
import pandas as pd
import numpy as np
import os
import psycopg2
import sqlalchemy
import string
import spacy
from spacy.symbols import ORTH
import scispacy
from collections import Counter
import re
from datetime import date, datetime, timedelta
import random
from sklearn.model_selection import GroupShuffleSplit, StratifiedShuffleSplit
from spellchecker import SpellChecker
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
dbschema='mimiciii'
cnx = sqlalchemy.create_engine('postgresql+psycopg2://aa5118:mimic@localhost:5432/mimic',
                    connect_args={'options': '-csearch_path={}'.format(dbschema)})

# %%
sql = """
  SELECT
      subject_id, hadm_id, ethnicity, diagnosis, admittime, dischtime, deathtime, admission_type
  FROM admissions
  WHERE admission_type NOT IN ('NEWBORN')
  ORDER BY subject_id, admittime
  --LIMIT 100;
"""

df_adm = pd.read_sql_query(sqlalchemy.text(sql), cnx)
print(df_adm.shape)
df_adm.head(20)
# Out:
# (51113, 8)
#     subject_id  hadm_id              ethnicity  \
# 0            3   145834                  WHITE
# 1            4   185777                  WHITE
# 2            6   107064                  WHITE
# 3            9   150750  UNKNOWN/NOT SPECIFIED
# 4           11   194540                  WHITE
# 5           12   112213                  WHITE
# 6           13   143045                  WHITE
# 7           17   194023                  WHITE
# 8           17   161087                  WHITE
# 9           18   188822                  WHITE
# 10          19   109235                  WHITE
# 11          20   157681                  WHITE
# 12          21   109451                  WHITE
# 13          21   111970                  WHITE
# 14          22   165315                  WHITE
# 15          23   152223                  WHITE
# 16          23   124321                  WHITE
# 17          24   161859                  WHITE
# 18          25   129635                  WHITE
# 19          26   197661  UNKNOWN/NOT SPECIFIED
#
#                                             diagnosis           admittime  \
# 0                                         HYPOTENSION 2101-10-20 19:08:00
# 1                 FEVER,DEHYDRATION,FAILURE TO THRIVE 2191-03-16 00:28:00
# 2                           CHRONIC RENAL FAILURE/SDA 2175-05-30 07:15:00
# 3                                     HEMORRHAGIC CVA 2149-11-09 13:06:00
# 4                                          BRAIN MASS 2178-04-16 06:18:00
# 5                               PANCREATIC CANCER/SDA 2104-08-07 10:15:00
# 6                             CORONARY ARTERY DISEASE 2167-01-08 18:43:00
# 7   PATIENT FORAMEN OVALE\ PATENT FORAMEN OVALE MI... 2134-12-27 07:15:00
# 8                                PERICARDIAL EFFUSION 2135-05-09 14:11:00
# 9                               HYPOGLYCEMIA;SEIZURES 2167-10-02 11:18:00
# 10                                       C-2 FRACTURE 2108-08-05 16:25:00
# 11  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS... 2183-04-28 09:45:00
# 12                           CONGESTIVE HEART FAILURE 2134-09-11 12:17:00
# 13                                             SEPSIS 2135-01-30 20:50:00
# 14                            BENZODIAZEPINE OVERDOSE 2196-04-09 12:26:00
# 15  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS... 2153-09-03 07:15:00
# 16                                         BRAIN MASS 2157-10-18 19:34:00
# 17                     INTERIOR MYOCARDIAL INFARCTION 2139-06-06 16:14:00
# 18                            ACUTE CORONARY SYNDROME 2160-11-02 02:06:00
# 19                                             V-TACH 2126-05-06 15:16:00
#
#              dischtime           deathtime admission_type
# 0  2101-10-31 13:58:00                 NaT      EMERGENCY
# 1  2191-03-23 18:41:00                 NaT      EMERGENCY
# 2  2175-06-15 16:00:00                 NaT       ELECTIVE
# 3  2149-11-14 10:15:00 2149-11-14 10:15:00      EMERGENCY
# 4  2178-05-11 19:00:00                 NaT      EMERGENCY
# 5  2104-08-20 02:57:00 2104-08-20 02:57:00       ELECTIVE
# 6  2167-01-15 15:15:00                 NaT      EMERGENCY
# 7  2134-12-31 16:05:00                 NaT       ELECTIVE
# 8  2135-05-13 14:40:00                 NaT      EMERGENCY
# 9  2167-10-04 16:15:00                 NaT      EMERGENCY
# 10 2108-08-11 11:29:00                 NaT      EMERGENCY
# 11 2183-05-03 14:45:00                 NaT       ELECTIVE
# 12 2134-09-24 16:15:00                 NaT      EMERGENCY
# 13 2135-02-08 02:08:00 2135-02-08 02:08:00      EMERGENCY
# 14 2196-04-10 15:54:00                 NaT      EMERGENCY
# 15 2153-09-08 19:10:00                 NaT       ELECTIVE
# 16 2157-10-25 14:00:00                 NaT      EMERGENCY
# 17 2139-06-09 12:48:00                 NaT      EMERGENCY
# 18 2160-11-05 14:55:00                 NaT      EMERGENCY
# 19 2126-05-13 15:00:00                 NaT      EMERGENCY

# %%
df_adm['next_admittime'] = df_adm.groupby('subject_id').admittime.shift(-1)
df_adm['next_admission_type'] = df_adm.groupby('subject_id').admission_type.shift(-1)
df_adm.head(20)
# Out:
#     subject_id  hadm_id              ethnicity  \
# 0            3   145834                  WHITE
# 1            4   185777                  WHITE
# 2            6   107064                  WHITE
# 3            9   150750  UNKNOWN/NOT SPECIFIED
# 4           11   194540                  WHITE
# 5           12   112213                  WHITE
# 6           13   143045                  WHITE
# 7           17   194023                  WHITE
# 8           17   161087                  WHITE
# 9           18   188822                  WHITE
# 10          19   109235                  WHITE
# 11          20   157681                  WHITE
# 12          21   109451                  WHITE
# 13          21   111970                  WHITE
# 14          22   165315                  WHITE
# 15          23   152223                  WHITE
# 16          23   124321                  WHITE
# 17          24   161859                  WHITE
# 18          25   129635                  WHITE
# 19          26   197661  UNKNOWN/NOT SPECIFIED
#
#                                             diagnosis           admittime  \
# 0                                         HYPOTENSION 2101-10-20 19:08:00
# 1                 FEVER,DEHYDRATION,FAILURE TO THRIVE 2191-03-16 00:28:00
# 2                           CHRONIC RENAL FAILURE/SDA 2175-05-30 07:15:00
# 3                                     HEMORRHAGIC CVA 2149-11-09 13:06:00
# 4                                          BRAIN MASS 2178-04-16 06:18:00
# 5                               PANCREATIC CANCER/SDA 2104-08-07 10:15:00
# 6                             CORONARY ARTERY DISEASE 2167-01-08 18:43:00
# 7   PATIENT FORAMEN OVALE\ PATENT FORAMEN OVALE MI... 2134-12-27 07:15:00
# 8                                PERICARDIAL EFFUSION 2135-05-09 14:11:00
# 9                               HYPOGLYCEMIA;SEIZURES 2167-10-02 11:18:00
# 10                                       C-2 FRACTURE 2108-08-05 16:25:00
# 11  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS... 2183-04-28 09:45:00
# 12                           CONGESTIVE HEART FAILURE 2134-09-11 12:17:00
# 13                                             SEPSIS 2135-01-30 20:50:00
# 14                            BENZODIAZEPINE OVERDOSE 2196-04-09 12:26:00
# 15  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS... 2153-09-03 07:15:00
# 16                                         BRAIN MASS 2157-10-18 19:34:00
# 17                     INTERIOR MYOCARDIAL INFARCTION 2139-06-06 16:14:00
# 18                            ACUTE CORONARY SYNDROME 2160-11-02 02:06:00
# 19                                             V-TACH 2126-05-06 15:16:00
#
#              dischtime           deathtime admission_type      next_admittime  \
# 0  2101-10-31 13:58:00                 NaT      EMERGENCY                 NaT
# 1  2191-03-23 18:41:00                 NaT      EMERGENCY                 NaT
# 2  2175-06-15 16:00:00                 NaT       ELECTIVE                 NaT
# 3  2149-11-14 10:15:00 2149-11-14 10:15:00      EMERGENCY                 NaT
# 4  2178-05-11 19:00:00                 NaT      EMERGENCY                 NaT
# 5  2104-08-20 02:57:00 2104-08-20 02:57:00       ELECTIVE                 NaT
# 6  2167-01-15 15:15:00                 NaT      EMERGENCY                 NaT
# 7  2134-12-31 16:05:00                 NaT       ELECTIVE 2135-05-09 14:11:00
# 8  2135-05-13 14:40:00                 NaT      EMERGENCY                 NaT
# 9  2167-10-04 16:15:00                 NaT      EMERGENCY                 NaT
# 10 2108-08-11 11:29:00                 NaT      EMERGENCY                 NaT
# 11 2183-05-03 14:45:00                 NaT       ELECTIVE                 NaT
# 12 2134-09-24 16:15:00                 NaT      EMERGENCY 2135-01-30 20:50:00
# 13 2135-02-08 02:08:00 2135-02-08 02:08:00      EMERGENCY                 NaT
# 14 2196-04-10 15:54:00                 NaT      EMERGENCY                 NaT
# 15 2153-09-08 19:10:00                 NaT       ELECTIVE 2157-10-18 19:34:00
# 16 2157-10-25 14:00:00                 NaT      EMERGENCY                 NaT
# 17 2139-06-09 12:48:00                 NaT      EMERGENCY                 NaT
# 18 2160-11-05 14:55:00                 NaT      EMERGENCY                 NaT
# 19 2126-05-13 15:00:00                 NaT      EMERGENCY                 NaT
#
#    next_admission_type
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7            EMERGENCY
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12           EMERGENCY
# 13                 NaN
# 14                 NaN
# 15           EMERGENCY
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN

# %%
# get rows where next admission is elective and replace with naT or nan
rows = df_adm.next_admission_type == 'ELECTIVE'
df_adm.loc[rows,'next_admittime'] = pd.NaT
df_adm.loc[rows,'next_admission_type'] = np.NaN

# %%
# sort by subject_ID and admission date
# it is safer to sort right before the fill in case something changed the order above
df_adm = df_adm.sort_values(['subject_id','admittime'])
# back fill (this will take a little while)
df_adm[['next_admittime','next_admission_type']] = df_adm.groupby(['subject_id'])[['next_admittime','next_admission_type']].fillna(method = 'bfill')

# %%
df_adm['days_next_admit']=  (df_adm.next_admittime - df_adm.dischtime).dt.total_seconds()/(24*60*60)

# %%
print(len(df_adm))
df_adm.head(100)
# 25           EMERGENCY      1678.557639
# 26                 NaN              NaN
# 27                 NaN              NaN
# 28           EMERGENCY         4.242361
# 29                 NaN              NaN
# ..                 ...              ...
# 70                 NaN              NaN
# 71           EMERGENCY       185.859028
# 72                 NaN              NaN
# 73                 NaN              NaN
# 74                 NaN              NaN
# 75                 NaN              NaN
# 76                 NaN              NaN
# 77                 NaN              NaN
# 78                 NaN              NaN
# 79                 NaN              NaN
# 80           EMERGENCY        10.495833
# 81                 NaN              NaN
# 82           EMERGENCY        18.378472
# 83                 NaN              NaN
# 84                 NaN              NaN
# 85           EMERGENCY      2474.120833
# 86           EMERGENCY       160.221528
# 87                 NaN              NaN
# 88                 NaN              NaN
# 89           EMERGENCY       145.979861
# 90           EMERGENCY       639.892361
# 91           EMERGENCY        11.533333
# 92           EMERGENCY        65.143056
# 93           EMERGENCY        14.914583
# 94           EMERGENCY        96.784028
# 95           EMERGENCY       206.109722
# 96           EMERGENCY        56.876389
# 97           EMERGENCY         4.598611
# 98           EMERGENCY        80.149306
# 99           EMERGENCY         2.654167
#
# [100 rows x 11 columns]

# %%
matplotlib.rcParams.update({'font.size': 18})

plt.hist(df_adm['days_next_admit'], bins=60)
plt.ylabel('Count')
plt.xlabel('Number of days since previous ICU stay')
plt.yscale('log')
plt.tight_layout()
plt.savefig('readmission-histogram.pdf')
# Out:
# /home/aa5118/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/aa5118/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
df_adm['30d_unplan_readmit'] = 'N'
df_adm.loc[df_adm['days_next_admit'] < 30, '30d_unplan_readmit'] = 'Y'

# %%
df_adm.head(50)
# Out:
#     subject_id  hadm_id                   ethnicity  \
# 0            3   145834                       WHITE
# 1            4   185777                       WHITE
# 2            6   107064                       WHITE
# 3            9   150750       UNKNOWN/NOT SPECIFIED
# 4           11   194540                       WHITE
# 5           12   112213                       WHITE
# 6           13   143045                       WHITE
# 7           17   194023                       WHITE
# 8           17   161087                       WHITE
# 9           18   188822                       WHITE
# 10          19   109235                       WHITE
# 11          20   157681                       WHITE
# 12          21   109451                       WHITE
# 13          21   111970                       WHITE
# 14          22   165315                       WHITE
# 15          23   152223                       WHITE
# 16          23   124321                       WHITE
# 17          24   161859                       WHITE
# 18          25   129635                       WHITE
# 19          26   197661       UNKNOWN/NOT SPECIFIED
# 20          28   162569                       WHITE
# 21          30   104557       UNKNOWN/NOT SPECIFIED
# 22          31   128652                       WHITE
# 23          32   175413                       WHITE
# 24          33   176176       UNKNOWN/NOT SPECIFIED
# 25          34   115799                       WHITE
# 26          34   144319                       WHITE
# 27          35   166707                       WHITE
# 28          36   182104                       WHITE
# 29          36   122659                       WHITE
# 30          36   165660                       WHITE
# 31          37   188670                       WHITE
# 32          38   185910                       WHITE
# 33          41   101757                       WHITE
# 34          42   119203       UNKNOWN/NOT SPECIFIED
# 35          43   146828                       WHITE
# 36          44   181750       UNKNOWN/NOT SPECIFIED
# 37          45   157907                       WHITE
# 24 2116-12-27 12:05:00                 NaT      EMERGENCY                 NaT
# 25 2186-07-20 16:00:00                 NaT      EMERGENCY 2191-02-23 05:23:00
# 26 2191-02-25 20:20:00                 NaT      EMERGENCY                 NaT
# 27 2122-02-20 15:30:00                 NaT       ELECTIVE                 NaT
# 28 2131-05-08 14:00:00                 NaT      EMERGENCY 2131-05-12 19:49:00
# 29 2131-05-25 13:30:00                 NaT      EMERGENCY                 NaT
# 30 2134-05-20 13:16:00                 NaT       ELECTIVE                 NaT
# 31 2183-08-26 18:54:00                 NaT      EMERGENCY                 NaT
# 32 2166-09-04 11:30:00                 NaT      EMERGENCY                 NaT
# 33 2133-01-27 15:45:00                 NaT       ELECTIVE                 NaT
# 34 2116-04-30 18:16:00                 NaT      EMERGENCY                 NaT
# 35 2186-10-11 18:00:00                 NaT      EMERGENCY                 NaT
# 36 2192-11-27 14:35:00                 NaT      EMERGENCY                 NaT
# 37 2129-06-20 14:39:00                 NaT      EMERGENCY                 NaT
# 38 2133-02-24 14:42:00                 NaT      EMERGENCY                 NaT
# 39 2186-11-28 14:05:00                 NaT       ELECTIVE                 NaT
# 40 2191-01-19 16:10:00                 NaT      EMERGENCY                 NaT
# 41 2170-03-23 18:00:00                 NaT      EMERGENCY                 NaT
# 42 2136-04-05 14:30:00                 NaT      EMERGENCY                 NaT
# 43 2104-01-08 10:30:00 2104-01-08 10:30:00      EMERGENCY                 NaT
# 44 2197-11-19 16:42:00                 NaT      EMERGENCY                 NaT
# 45 2118-07-20 12:30:00                 NaT       ELECTIVE 2119-01-04 18:12:00
# 46 2119-02-03 01:35:00 2119-02-03 01:35:00      EMERGENCY                 NaT
# 47 2113-02-19 15:30:00                 NaT      EMERGENCY                 NaT
# 48 2169-01-07 14:20:00                 NaT      EMERGENCY                 NaT
# 49 2143-03-18 13:01:00                 NaT      EMERGENCY                 NaT
#
#    next_admission_type  days_next_admit 30d_unplan_readmit
# 0                  NaN              NaN                  N
# 1                  NaN              NaN                  N
# 2                  NaN              NaN                  N
# 3                  NaN              NaN                  N
# 4                  NaN              NaN                  N
# 5                  NaN              NaN                  N
# 6                  NaN              NaN                  N
# 7            EMERGENCY       128.920833                  N
# 8                  NaN              NaN                  N
# 9                  NaN              NaN                  N
# 10                 NaN              NaN                  N
# 11                 NaN              NaN                  N
# 12           EMERGENCY       128.190972                  N
# 13                 NaN              NaN                  N
# 14                 NaN              NaN                  N
# 15           EMERGENCY      1501.016667                  N
# 16                 NaN              NaN                  N
# 17                 NaN              NaN                  N
# 18                 NaN              NaN                  N
# 19                 NaN              NaN                  N
# 20                 NaN              NaN                  N
# 21                 NaN              NaN                  N
# 22                 NaN              NaN                  N
# 23                 NaN              NaN                  N
# 24                 NaN              NaN                  N
# 25           EMERGENCY      1678.557639                  N
# 26                 NaN              NaN                  N
# 27                 NaN              NaN                  N
# 28           EMERGENCY         4.242361                  Y
# 29                 NaN              NaN                  N
# 30                 NaN              NaN                  N
# 31                 NaN              NaN                  N
# 32                 NaN              NaN                  N
# 33                 NaN              NaN                  N
# 34                 NaN              NaN                  N
# 35                 NaN              NaN                  N
# 36                 NaN              NaN                  N
# 37                 NaN              NaN                  N
# 38                 NaN              NaN                  N
# 39                 NaN              NaN                  N
# 40                 NaN              NaN                  N
# 41                 NaN              NaN                  N
# 42                 NaN              NaN                  N
# 43                 NaN              NaN                  N
# 44                 NaN              NaN                  N
# 45           EMERGENCY       168.237500                  N
# 46                 NaN              NaN                  N
# 47                 NaN              NaN                  N
# 48                 NaN              NaN                  N
# 49                 NaN              NaN                  N

# %%
#df_adm['30d_unplan_readmit'].value_counts().plot(kind='bar')
plt.bar(df_adm['30d_unplan_readmit'].unique(),height=df_adm['30d_unplan_readmit'].value_counts())
plt.ylabel('Number of ICU stays')
plt.xlabel('Previous stay < 30 days ago')
plt.tight_layout()
plt.savefig('30d-readmission-bar.pdf')

# %%
readmit_count = df_adm.subject_id[(df_adm['30d_unplan_readmit']) == 'Y'].count()
ratio = readmit_count/df_adm['30d_unplan_readmit'].count()
ratio
# Out:
# 0.05877174104435271

# %%
df_adm['ethnicity'].value_counts().plot(kind='bar')

# %%
sorted(df_adm.ethnicity.unique())
# Out:
# ['AMERICAN INDIAN/ALASKA NATIVE',
#  'AMERICAN INDIAN/ALASKA NATIVE FEDERALLY RECOGNIZED TRIBE',
#  'ASIAN',
#  'ASIAN - ASIAN INDIAN',
#  'ASIAN - CAMBODIAN',
#  'ASIAN - CHINESE',
#  'ASIAN - FILIPINO',
#  'ASIAN - JAPANESE',
#  'ASIAN - KOREAN',
#  'ASIAN - OTHER',
#  'ASIAN - THAI',
#  'ASIAN - VIETNAMESE',
#  'BLACK/AFRICAN',
#  'BLACK/AFRICAN AMERICAN',
#  'BLACK/CAPE VERDEAN',
#  'BLACK/HAITIAN',
#  'CARIBBEAN ISLAND',
#  'HISPANIC OR LATINO',
#  'HISPANIC/LATINO - CENTRAL AMERICAN (OTHER)',
#  'HISPANIC/LATINO - COLOMBIAN',
#  'HISPANIC/LATINO - CUBAN',
#  'HISPANIC/LATINO - DOMINICAN',
#  'HISPANIC/LATINO - GUATEMALAN',
#  'HISPANIC/LATINO - HONDURAN',
#  'HISPANIC/LATINO - MEXICAN',
#  'HISPANIC/LATINO - PUERTO RICAN',
#  'HISPANIC/LATINO - SALVADORAN',
#  'MIDDLE EASTERN',
#  'MULTI RACE ETHNICITY',
#  'NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER',
#  'OTHER',
#  'PATIENT DECLINED TO ANSWER',
#  'PORTUGUESE',
#  'SOUTH AMERICAN',
#  'UNABLE TO OBTAIN',
#  'UNKNOWN/NOT SPECIFIED',
#  'WHITE',
#  'WHITE - BRAZILIAN',
#  'WHITE - EASTERN EUROPEAN',
#  'WHITE - OTHER EUROPEAN',
#  'WHITE - RUSSIAN']

# %%
asian = dict.fromkeys(['ASIAN','ASIAN - ASIAN INDIAN','ASIAN - CAMBODIAN','ASIAN - CHINESE','ASIAN - FILIPINO',
 'ASIAN - JAPANESE',
 'ASIAN - KOREAN',
 'ASIAN - OTHER',
 'ASIAN - THAI',
 'ASIAN - VIETNAMESE',
 'MIDDLE EASTERN'], 'asian')    
white = dict.fromkeys([ 'WHITE', 'WHITE - BRAZILIAN', 'WHITE - EASTERN EUROPEAN', 'WHITE - OTHER EUROPEAN', 'WHITE - RUSSIAN'], 'white')
black = dict.fromkeys([ 'BLACK/AFRICAN', 'BLACK/AFRICAN AMERICAN', 'BLACK/CAPE VERDEAN','BLACK/HAITIAN'], 'black')
hispanic = dict.fromkeys([ 'HISPANIC OR LATINO', 'HISPANIC/LATINO - CENTRAL AMERICAN (OTHER)', 'HISPANIC/LATINO - COLOMBIAN',
 'HISPANIC/LATINO - CUBAN',
 'HISPANIC/LATINO - DOMINICAN',
 'HISPANIC/LATINO - GUATEMALAN',
 'HISPANIC/LATINO - HONDURAN',
 'HISPANIC/LATINO - MEXICAN',
 'HISPANIC/LATINO - PUERTO RICAN',
 'HISPANIC/LATINO - SALVADORAN',
 'PORTUGUESE',
 'SOUTH AMERICAN'], 'hispanic')

df_adm = df_adm.replace(asian)
df_adm = df_adm.replace(white)
df_adm = df_adm.replace(black)
df_adm = df_adm.replace(hispanic)

allowed_vals = ['asian', 'black', 'white', 'hispanic']
df_adm.loc[~df_adm['ethnicity'].isin(allowed_vals), 'ethnicity'] = "other"
sorted(df_adm.ethnicity.unique())
# Out:
# ['asian', 'black', 'hispanic', 'other', 'white']

# %%
df_adm['ethnicity'].value_counts().plot(kind='bar')

# %%
nlp = spacy.load('en_core_sci_md')

def tokenise_text(text):
    
    text = text.lower()
    tokens = nlp.tokenizer(text)
    tokenised_text = ""
    
    for token in tokens:
        tokenised_text = tokenised_text + str(token) + " "
    
    tokenised_text = ' '.join(tokenised_text.split())
    
    return tokenised_text

# %%
df_adm.diagnosis = df_adm.diagnosis.apply(str)
print(df_adm.diagnosis)
# Out:
# 0                                              HYPOTENSION
# 1                      FEVER,DEHYDRATION,FAILURE TO THRIVE
# 2                                CHRONIC RENAL FAILURE/SDA
# 3                                          HEMORRHAGIC CVA
# 4                                               BRAIN MASS
# 5                                    PANCREATIC CANCER/SDA
# 6                                  CORONARY ARTERY DISEASE
# 7        PATIENT FORAMEN OVALE\ PATENT FORAMEN OVALE MI...
# 8                                     PERICARDIAL EFFUSION
# 9                                    HYPOGLYCEMIA;SEIZURES
# 10                                            C-2 FRACTURE
# 11       CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...
# 12                                CONGESTIVE HEART FAILURE
# 13                                                  SEPSIS
# 14                                 BENZODIAZEPINE OVERDOSE
# 15       CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...
# 16                                              BRAIN MASS
# 17                          INTERIOR MYOCARDIAL INFARCTION
# 18                                 ACUTE CORONARY SYNDROME
# 19                                                  V-TACH
# 20       CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...
# 21                                    UNSTABLE ANGINA\CATH
# 22                                      STATUS EPILEPTICUS
# 23                                   TRACHEAL STENOSIS/SDA
# 24                                        SEPSIS;TELEMETRY
# 25                                         CHEST PAIN\CATH
# 26                                             BRADYCARDIA
# 27       AORTIC VALVE DISEASE\CORONARY ARTERY BYPASS GR...
# 28       CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...
# 29                          CHEST PAIN/SHORTNESS OF BREATH
#                                ...
# 51083                 CONGESTIVE HEART FAILURE;HYPOTENSION
# 51084                    SPINAL ARTERIOVENOUS MALFORMATION
# 51085                                            PNEUMONIA
# 51086                              CORONARY ARTERY DISEASE
# 51087        AORTIC STENOSIS\AORTIC VALVE REPLACEMENT /SDA
# 51088                                         HYPONATREMIA
# 51089                              END STAGE LIVER DISEASE
# 51090                                DIABETIC KETOACIDOSIS
# 51091                                       PELVIC ABSCESS
# 51092                              SUBARACHNOID HEMORRHAGE
# 51093                                    SYNCOPE;TELEMETRY
# 51094                                            PNEUMONIA
# 51095    CARDIOMYOPATHY;CONGESTIVE HEART FAILURE\CARDIA...
# 51096                                  PULMONARY EDEMA,ARF
# 51097     CHEST PAIN;CONGESTIVE HEART FAILURE\CARDIAC CATH
# 51098                                         PANCREATITIS
# 51099                                       SUBDURAL BLEED
# 51100                                       R/O CEREBRITIS
# 51101                                       LOWER GI BLEED
# 51102                                 COMPLETE HEART BLOCK
# 51103                                               SEPSIS
# 51104                                                  TVR
# 51105                                  SHORTNESS OF BREATH
# 51106                          BIVENTRICULAR HEART FAILURE
# 51107    ST ELEVATION MYOCARDIAL INFARCTION;CORONARY AR...
# 51108                                                FEVER
# 51109                                   DIVERTICULITIS/SDA
# 51110                           RETROPERITONEAL HEMORRHAGE
# 51111                        ABDOMINAL AORTIC ANEURYSM/SDA
# 51112                                SPONDYLOLISTHESIS/SDA
# Name: diagnosis, Length: 51113, dtype: object

# %%
df_adm["diagnosis"] = df_adm["diagnosis"].apply(tokenise_text)
df_adm.head()
# Out:
#    subject_id  hadm_id ethnicity                                diagnosis  \
# 0           3   145834     white                              hypotension
# 1           4   185777     white  fever , dehydration , failure to thrive
# 2           6   107064     white                chronic renal failure/sda
# 3           9   150750     other                          hemorrhagic cva
# 4          11   194540     white                               brain mass
#
#             admittime           dischtime           deathtime admission_type  \
# 0 2101-10-20 19:08:00 2101-10-31 13:58:00                 NaT      EMERGENCY
# 1 2191-03-16 00:28:00 2191-03-23 18:41:00                 NaT      EMERGENCY
# 2 2175-05-30 07:15:00 2175-06-15 16:00:00                 NaT       ELECTIVE
# 3 2149-11-09 13:06:00 2149-11-14 10:15:00 2149-11-14 10:15:00      EMERGENCY
# 4 2178-04-16 06:18:00 2178-05-11 19:00:00                 NaT      EMERGENCY
#
#   next_admittime next_admission_type  days_next_admit 30d_unplan_readmit
# 0            NaT                 NaN              NaN                  N
# 1            NaT                 NaN              NaN                  N
# 2            NaT                 NaN              NaN                  N
# 3            NaT                 NaN              NaN                  N
# 4            NaT                 NaN              NaN                  N

# %%
df_adm_csv = df_adm[['subject_id','hadm_id', 'ethnicity','diagnosis','admission_type','30d_unplan_readmit']]

# %%
df_adm_csv.to_csv('../data/df_adm.csv',index=False)
